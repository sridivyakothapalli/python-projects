# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5ee15ed8-f178-49ec-bfcd-c017829adc40" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ee15ed8-f178-49ec-bfcd-c017829adc40">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cust=pd.read_csv('customer_churn.csv')

# %%
cust.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# *Extract the 5th column and store it in ‘customer_5*

# %% [markdown]
# ata Manipulation:
# ● Extract the 5th column and store it in ‘customer_5’
# ● Extract the 15th column and store it in ‘customer_15

# %%
customer_5=cust['Dependents']

# %%
customer_5
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7043, dtype: object

# %%
customer_15=cust.iloc[0:7042,15]
customer_15
# Out:
# 0       Month-to-month
# 1             One year
# 2       Month-to-month
# 3             One year
# 4       Month-to-month
#              ...
# 7037          Two year
# 7038          One year
# 7039          One year
# 7040    Month-to-month
# 7041    Month-to-month
# Name: Contract, Length: 7042, dtype: object

# %% [markdown]
# *extract all the male senior citizens whose payment method is electronic
# check and store the result in ‘senior_male_electronic’*

# %%
senior_male_electronic=cust[(cust['PaymentMethod']=='Electronic check') & (cust['gender']== 'Male')]
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 14    5129-JLPIS   Male              0      No         No      25
# 20    8779-QRDMV   Male              1      No         No       1
# 26    6467-CHFZW   Male              0     Yes        Yes      47
# 27    8665-UTDHZ   Male              0     Yes        Yes       1
# 36    6047-YHPVI   Male              0      No         No       5
# ...          ...    ...            ...     ...        ...     ...
# 7014  9053-EJUNL   Male              0      No         No      41
# 7020  9837-FWLCH   Male              0     Yes        Yes      12
# 7021  1699-HPSBG   Male              0      No         No      12
# 7022  7203-OYKCT   Male              0      No         No      72
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 14            Yes                No     Fiber optic                  Yes  ...
# ...

# %% [markdown]
# Extract all those customers whose tenure is greater than 70 months or
# their monthly charges is more than $100 and store the result in
# ‘customer_total_tenure’

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
cust[['tenure','MonthlyCharges']]
# Out:
#       tenure  MonthlyCharges
# 0          1           29.85
# 1         34           56.95
# 2          2           53.85
# 3         45           42.30
# 4          2           70.70
# ...      ...             ...
# 7038      24           84.80
# 7039      72          103.20
# 7040      11           29.60
# 7041       4           74.40
# 7042      66          105.65
#
# [7043 rows x 2 columns]

# %%
customer_total_tenure=cust[(cust['tenure']>70) | (cust['MonthlyCharges']>100)]

# %% [markdown]
# Extract all the customers whose contract is of two years, payment method
# is mailed check and the value of churn is ‘Yes’ and store the result in
# ‘two_mail_yes’

# %%
two_mail_yes=cust[(cust['Contract']=='Two year') & (cust['PaymentMethod']=='Mailed check') & (cust['Churn']=='Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
cust['Contract']
# Out:
# 0       Month-to-month
# 1             One year
# 2       Month-to-month
# 3             One year
# 4       Month-to-month
#              ...
# 7038          One year
# 7039          One year
# 7040    Month-to-month
# 7041    Month-to-month
# 7042          Two year
# Name: Contract, Length: 7043, dtype: object

# %% [markdown]
# Extract 333 random records from the customer_churndataframe and store
# the result in ‘customer_333’

# %%
customer_333=cust[0:334]
customer_333
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    7590-VHVEG  Female              0     Yes         No       1
# 1    5575-GNVDE    Male              0      No         No      34
# 2    3668-QPYBK    Male              0      No         No       2
# 3    7795-CFOCW    Male              0      No         No      45
# 4    9237-HQITU  Female              0      No         No       2
# ..          ...     ...            ...     ...        ...     ...
# 329  2739-CACDQ  Female              1      No         No      17
# 330  9385-EHGDO  Female              0     Yes        Yes      35
# 331  9498-FIMXL  Female              0      No         No       8
# 332  2379-GYFLQ    Male              0      No         No      46
# 333  0122-OAHPZ  Female              0      No         No       7
#
#     PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0             No  No phone service             DSL                   No  ...
# ...

# %% [markdown]
# Get the count of different levels from the ‘Churn’ column

# %%
cust['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
cust['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# total_charges group by contract

# %%
cust['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
cust['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
groupby_contract=cust.groupby('Contract')
groupby_contract

# %%
groupby_contract.groups
# Out:
# {'Month-to-month': [0, 2, 4, 5, 6, 7, 8, 10, 13, 14, 18, 19, 20, 22, 24, 25, 26, 27, 29, 31, 33, 34, 36, 37, 38, 39, 44, 45, 46, 47, 50, 51, 52, 53, 55, 60, 61, 64, 65, 69, 70, 74, 77, 78, 80, 81, 82, 83, 85, 89, 90, 91, 93, 95, 97, 99, 100, 101, 105, 110, 112, 113, 115, 117, 119, 121, 122, 123, 124, 126, 128, 130, 131, 133, 134, 136, 139, 141, 147, 149, 150, 151, 154, 155, 156, 160, 161, 162, 166, 168, 169, 171, 175, 176, 177, 178, 180, 181, 182, 184, ...], 'One year': [1, 3, 9, 12, 16, 21, 32, 40, 42, 54, 56, 57, 63, 66, 71, 75, 76, 79, 86, 96, 102, 103, 106, 107, 108, 111, 120, 129, 143, 146, 148, 152, 157, 164, 170, 173, 174, 179, 183, 188, 190, 200, 205, 209, 213, 222, 224, 225, 226, 242, 246, 249, 250, 253, 257, 264, 285, 291, 292, 300, 309, 315, 317, 320, 323, 331, 332, 335, 343, 344, 349, 351, 359, 362, 368, 370, 373, 375, 379, 380, 387, 399, 400, 401, 403, 406, 411, 422, 423, 426, 429, 436, 442, 450, 456, 467, 470, 483, 493, 495, ...], 'Two year': [11, 15, 17, 23, 28, 30, 35
# ...

# %%
groupby_contract.get_group('Month-to-month')
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
groupby_contract['TotalCharges'].count()
# Out:
# Contract
# Month-to-month    3875
# One year          1473
# Two year          1695
# Name: TotalCharges, dtype: int64

# %% [markdown]
# Data Visualization:
# ● Build a bar-plot for the ’InternetService’ column:
#
# a. Set x-axis label to ‘Categories of Internet Service’
#
# b. Set y-axis label to ‘Count of Categories’
#
# c. Set the title of plot to be ‘Distribution of Internet Service’
#
# d. Set the color of the bars

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=cust['InternetService'].unique()
y=cust['InternetService'].value_counts()
plt.bar(x,y,color='skyblue',width=0.5)
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of Categories')
plt.title('Distribution of Internet Service')
plt.show()

# %% [markdown]
# Build a histogram for the ‘tenure’ column:
#
# a. Set the number of bins to be 30
#
# b. Set the color of the bins to be ‘green’
#
# c. Assign the title ‘Distribution

# %%
plt.hist(cust['tenure'],bins=30,color='green')
plt.title('Distribution')
plt.show()

# %% [markdown]
# Build a scatter-plot between ‘MonthlyCharges’ and ‘tenure’. Map
# ‘MonthlyCharges’ to the y-axis and ‘tenure’ to the ‘x-axis’:
#
# a. Assign the points a color of ‘brown’
#
# b. Set the x-axis label to ‘Tenure of customer’
#
# . Set the y-axis label to ‘Monthly Charges of customer’
#
# d. Set the title to ‘Tenure vs Monthly Charges’
#
# e. Build a box-plot between ‘tenure’ & ‘Contract’. Map ‘tenure’ on the
# y-axis &
#
# f. ‘Contract’ on the x-axis

# %%
plt.scatter(cust['tenure'],cust['MonthlyCharges'],color='brown')
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly Charges of customer')
plt.title('Tenure vs Monthly Charges')
plt.show()

# %%
import seaborn as sns

# %%
sns.catplot(x='tenure',y='Contract',data=cust,kind='box')
#plt.show()
